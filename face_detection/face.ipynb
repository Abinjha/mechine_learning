# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('face3.jpg')

# %%
plt.imshow(img)

# %%
conv_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(conv_img)

# %%
face=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
face
# Out:
# < cv2.CascadeClassifier 0000027396219810>

# %%
faces=face.detectMultiScale(conv_img)
faces
# Out:
# array([[ 797,  112,  155,  155],
#        [1119,  132,  149,  149],
#        [ 560,  150,  151,  151],
#        [ 254,  175,  136,  136],
#        [   5,  194,   72,   72]])

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(conv_img,(x,y),(x+w,y+h),(255,0,0),3)
plt.imshow(conv_img)
