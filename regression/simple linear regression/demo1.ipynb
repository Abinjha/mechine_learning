# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sqft=[2600,2800,3200,3500,4000]
prize=[5500000,5850000,6100000,6700000,7200000]
plt.scatter(sqft,prize)
plt.xlabel('square ft',color='r')
plt.ylabel('prize',color='r')
plt.grid()
