# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('flight_dataset.csv')
df
# Out:
#            Airline    Source Destination  Total_Stops  Price  Date  Month  \
# 0           IndiGo  Banglore   New Delhi            0   3897    24      3
# 1        Air India   Kolkata    Banglore            2   7662     1      5
# 2      Jet Airways     Delhi      Cochin            2  13882     9      6
# 3           IndiGo   Kolkata    Banglore            1   6218    12      5
# 4           IndiGo  Banglore   New Delhi            1  13302     1      3
# ...            ...       ...         ...          ...    ...   ...    ...
# 10678     Air Asia   Kolkata    Banglore            0   4107     9      4
# 10679    Air India   Kolkata    Banglore            0   4145    27      4
# 10680  Jet Airways  Banglore       Delhi            0   7229    27      4
# 10681      Vistara  Banglore   New Delhi            0  12648     1      3
# 10682    Air India     Delhi      Cochin            2  11753     9      5
#
#        Year  Dep_hours  Dep_min  Arrival_hours  Arrival_min  Duration_hours  \
# ...

# %%
df.head()
# Out:
#        Airline    Source Destination  Total_Stops  Price  Date  Month  Year  \
# 0       IndiGo  Banglore   New Delhi            0   3897    24      3  2019
# 1    Air India   Kolkata    Banglore            2   7662     1      5  2019
# 2  Jet Airways     Delhi      Cochin            2  13882     9      6  2019
# 3       IndiGo   Kolkata    Banglore            1   6218    12      5  2019
# 4       IndiGo  Banglore   New Delhi            1  13302     1      3  2019
#
#    Dep_hours  Dep_min  Arrival_hours  Arrival_min  Duration_hours  \
# 0         22       20              1           10               2
# 1          5       50             13           15               7
# 2          9       25              4           25              19
# 3         18        5             23           30               5
# 4         16       50             21           35               4
#
#    Duration_min
# 0            50
# 1            25
# 2             0
# 3            25
# 4            45

# %%
df.tail()
# Out:
#            Airline    Source Destination  Total_Stops  Price  Date  Month  \
# 10678     Air Asia   Kolkata    Banglore            0   4107     9      4
# 10679    Air India   Kolkata    Banglore            0   4145    27      4
# 10680  Jet Airways  Banglore       Delhi            0   7229    27      4
# 10681      Vistara  Banglore   New Delhi            0  12648     1      3
# 10682    Air India     Delhi      Cochin            2  11753     9      5
#
#        Year  Dep_hours  Dep_min  Arrival_hours  Arrival_min  Duration_hours  \
# 10678  2019         19       55             22           25               2
# 10679  2019         20       45             23           20               2
# 10680  2019          8       20             11           20               3
# 10681  2019         11       30             14           10               2
# 10682  2019         10       55             19           15               8
#
#        Duration_min
# 10678            30
# 10679            35
# ...

# %%
df.isna().sum()
# Out:
# Airline           0
# Source            0
# Destination       0
# Total_Stops       0
# Price             0
# Date              0
# Month             0
# Year              0
# Dep_hours         0
# Dep_min           0
# Arrival_hours     0
# Arrival_min       0
# Duration_hours    0
# Duration_min      0
# dtype: int64

# %%
df.dtypes
# Out:
# Airline           object
# Source            object
# Destination       object
# Total_Stops        int64
# Price              int64
# Date               int64
# Month              int64
# Year               int64
# Dep_hours          int64
# Dep_min            int64
# Arrival_hours      int64
# Arrival_min        int64
# Duration_hours     int64
# Duration_min       int64
# dtype: object

# %%
a1=df['Airline'].value_counts()

# %%
plt.barh(a1.index,a1.values)
plt.ylabel('Airline')
plt.xlabel('counts')
# Out:
# Text(0.5, 0, 'counts')

# %%
a2=df['Source'].value_counts()
plt.bar(a2.index,a2,color='g')
plt.xlabel('Location')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
a3=df['Destination'].value_counts()
plt.bar(a3.index,a3,color='r')
plt.xlabel('destination')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
#get dummies
dfg=pd.get_dummies(df[['Airline','Source','Destination']],drop_first=True,dtype=int)

# %%
df2=pd.concat([df,dfg],axis=1)
df2
# Out:
#            Airline    Source Destination  Total_Stops  Price  Date  Month  \
# 0           IndiGo  Banglore   New Delhi            0   3897    24      3
# 1        Air India   Kolkata    Banglore            2   7662     1      5
# 2      Jet Airways     Delhi      Cochin            2  13882     9      6
# 3           IndiGo   Kolkata    Banglore            1   6218    12      5
# 4           IndiGo  Banglore   New Delhi            1  13302     1      3
# ...            ...       ...         ...          ...    ...   ...    ...
# 10678     Air Asia   Kolkata    Banglore            0   4107     9      4
# 10679    Air India   Kolkata    Banglore            0   4145    27      4
# 10680  Jet Airways  Banglore       Delhi            0   7229    27      4
# 10681      Vistara  Banglore   New Delhi            0  12648     1      3
# 10682    Air India     Delhi      Cochin            2  11753     9      5
#
#        Year  Dep_hours  Dep_min  ...  Airline_Vistara Premium economy  \
# ...

# %%
df2.drop(['Airline','Source','Destination'],axis=1,inplace=True)
df2.shape
# Out:
# (10683, 31)

# %%
x=df2.drop(['Price'],axis=1)
y=df2['Price']
# Out:
# 0         3897
# 1         7662
# 2        13882
# 3         6218
# 4        13302
#          ...
# 10678     4107
# 10679     4145
# 10680     7229
# 10681    12648
# 10682    11753
# Name: Price, Length: 10683, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 5043.81229846, 11699.69151026, 10748.5845044 , ...,
#         6919.89101129, 11790.68679249,  5406.5020514 ], shape=(7478,))

# %%
df1=pd.DataFrame({'Actual_value':y_test,'Predicted_value':y_pred,'difference is':y_test-y_pred})
df1
# Out:
#       Actual_value  Predicted_value  difference is
# 4551          4804      5043.812298    -239.812298
# 7226         12557     11699.691510     857.308490
# 6202          7005     10748.584504   -3743.584504
# 4235          6513     11126.289391   -4613.289391
# 9664          7870      7137.137921     732.862079
# ...            ...              ...            ...
# 2895         14571     11429.510073    3141.489927
# 7813          4804      4212.852915     591.147085
# 905           6442      6919.891011    -477.891011
# 5192         14151     11790.686792    2360.313208
# 235           4409      5406.502051    -997.502051
#
# [7478 rows x 3 columns]

# %%
from sklearn.metrics import  mean_absolute_error,mean_squared_error, root_mean_squared_error, mean_absolute_percentage_error,r2_score
print('MAE is',mean_absolute_error(y_test,y_pred))
print('MSE is',mean_squared_error(y_test,y_pred))
print('RMSE id',root_mean_squared_error(y_test,y_pred))
print('MAPE is',mean_absolute_percentage_error(y_test,y_pred))
print('R2score is',r2_score(y_test,y_pred))
# Out:
# MAE is 1970.8367148456255
# MSE is 8134908.418178429
# RMSE id 2852.17608470768
# MAPE is 0.23667764281599057
# R2score is 0.6183788755096513
